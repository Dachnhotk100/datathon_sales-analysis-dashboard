# %%
import pandas as pd
import os

# THAY ĐỔI DÒNG NÀY:
path = r"D:\Codes\Sales-Analysis-Dataset" 
#         ^ dán đường dẫn bạn vừa copy vào đây

# ... (phần còn lại của code giữ nguyên) ...
files = [file for file in os.listdir(path) if file.endswith('.csv')]
all_months_data = pd.DataFrame()
for file in files:
    df = pd.read_csv(os.path.join(path, file))
    all_months_data = pd.concat([all_months_data, df])

all_months_data.to_csv("all_sales_data.csv", index=False)
print("Đã gộp thành công 12 tệp thành all_sales_data.csv")
# Out:
# Đã gộp thành công 12 tệp thành all_sales_data.csv
